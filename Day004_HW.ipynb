# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events') 
r.text

# 上面給的接口已無法使用 (TimeoutError: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。)
# 因此用sample的代替
# Out:
# '[{"id":"16383728786","type":"PullRequestEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":342968461,"name":"Botvy/Botvy","url":"https://api.github.com/repos/Botvy/Botvy"},"payload":{"action":"opened","number":103,"pull_request":{"url":"https://api.github.com/repos/Botvy/Botvy/pulls/103","id":645621863,"node_id":"MDExOlB1bGxSZXF1ZXN0NjQ1NjIxODYz","html_url":"https://github.com/Botvy/Botvy/pull/103","diff_url":"https://github.com/Botvy/Botvy/pull/103.diff","patch_url":"https://github.com/Botvy/Botvy/pull/103.patch","issue_url":"https://api.github.com/repos/Botvy/Botvy/issues/103","number":103,"state":"open","locked":false,"title":"Bump @types/node from 15.0.3 to 15.3.0","user":{"login":"dependabot[bot]","id":49699333,"node_id":"MDM6Qm90NDk2OTkzMzM=","avatar_url":"https://avatars.githubusercontent.com/in/29110?v=4","gravatar_id":"","url":"https://api.github.com/users/dependabot%5Bbot%5D","html_url":"https://github.com/apps/dependabot","followers_url":"https://api.github.com/users/dependabot%5Bbot%5D/followers","following_url":"https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/dependabot%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/dependabot%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/dependabot%5Bbot%5D/repos","events_url":"https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/dependabot%5Bbot%5D/received_events","type":"Bot","site_admin":false},"body":"Bumps [@types/node](https://github.com/DefinitelyTyped/DefinitelyTyped/tree/HEAD/types/node) from 15.0.3 to 15.3.0.\\n<details>\\n<summary>Commits</summary>\\n<ul>\\n<li>See full diff in <a href=\\"https://github.com/DefinitelyTyped/DefinitelyTyped/commits/HEAD/types/node\\">compare view</a></li>\\n</ul>\\n</details>\\n<br />\\n\\n\\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=@types/node&package-manager=npm_and_yarn&previous-version=15.0.3&new-version=15.3.0)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\\n\\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\\n\\n[//]: # (dependabot-automerge-start)\\n[//]: # (dependabot-automerge-end)\\n\\n---\\n\\n<details>\\n<summary>Dependabot commands and options</summary>\\n<br />\\n\\nYou can trigger Dependabot actions by commenting on this PR:\\n- `@dependabot rebase` will rebase this PR\\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\\n- `@dependabot merge` will merge this PR after your CI passes on it\\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\\n- `@dependabot reopen` will reopen this PR if it is closed\\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\\n\\n\\n</details>","created_at":"2021-05-17T07:49:11Z","updated_at":"2021-05-17T07:49:11Z","closed_at":null,"merged_at":null,"merge_commit_sha":null,"assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"draft":false,"commits_url":"https://api.github.com/repos/Botvy/Botvy/pulls/103/commits","review_comments_url":"https://api.github.com/repos/Botvy/Botvy/pulls/103/comments" ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '16383728786',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 342968461,
#    'name': 'Botvy/Botvy',
#    'url': 'https://api.github.com/repos/Botvy/Botvy'},
#   'payload': {'action': 'opened',
#    'number': 103,
#    'pull_request': {'url': 'https://api.github.com/repos/Botvy/Botvy/pulls/103',
#     'id': 645621863,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjQ1NjIxODYz',
#     'html_url': 'https://github.com/Botvy/Botvy/pull/103',
#     'diff_url': 'https://github.com/Botvy/Botvy/pull/103.diff',
#     'patch_url': 'https://github.com/Botvy/Botvy/pull/103.patch',
#     'issue_url': 'https://api.github.com/repos/Botvy/Botvy/issues/103',
#     'number': 103,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump @types/node from 15.0.3 to 15.3.0',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [@types/node](https://github.com/DefinitelyTyped/DefinitelyTyped/tree/HEAD/types/node) from 15.0.3 to 15.3.0.\n<details>\n<summary>Commits</summary>\n<ul>\n<li>See full diff in <a href="https://github.com/DefinitelyTyped/DefinitelyTyped/commits/HEAD/types/node">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=@types/node&package-manager=npm_and_yarn&previous-version=15.0.3&new-version=15.3.0)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n\n\n</details>',
#     'created_at': '2021-05-17T07:49:11Z',
#     'updated_at': '2021-05-17T07:49:11Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Botvy/Botvy/pulls/103/commits',
#     'review_comments_url': 'https://api.github.com/repos/Botvy/Botvy/pulls/103/comments',
#     'review_comment_url': 'https://api.github.com/repos/Botvy/Botvy/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Botvy/Botvy/issues/103/comments',
#     'statuses_url': 'https://api.github.com/repos/Botvy/Botvy/statuses/935b1a63bc2cdb224ffb3dfaf20d000f6fe8e61c',
#     'head': {'label': 'Botvy:dependabot/npm_and_yarn/types/node-15.3.0',
#      'ref': 'dependabot/npm_and_yarn/types/node-15.3.0',
#      'sha': '935b1a63bc2cdb224ffb3dfaf20d000f6fe8e61c',
#      'user': {'login': 'Botvy',
#       'id': 57847101,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU3ODQ3MTAx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/57847101?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Botvy',
#       'html_url': 'https://github.com/Botvy',
#       'followers_url': 'https://api.github.com/users/Botvy/followers',
#       'following_url': 'https://api.github.com/users/Botvy/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Botvy/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Botvy/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Botvy/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Botvy/orgs',
#       'repos_url': 'https://api.github.com/users/Botvy/repos',
#       'events_url': 'https://api.github.com/users/Botvy/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Botvy/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 342968461,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNDI5Njg0NjE=',
#       'name': 'Botvy',
#       'full_name': 'Botvy/Botvy',
#       'private': False,
#       'owner': {'login': 'Botvy',
#        'id': 57847101,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU3ODQ3MTAx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/57847101?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Botvy',
#        'html_url': 'https://github.com/Botvy',
#        'followers_url': 'https://api.github.com/users/Botvy/followers',
#        'following_url': 'https://api.github.com/users/Botvy/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Botvy/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Botvy/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Botvy/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Botvy/orgs',
#        'repos_url': 'https://api.github.com/users/Botvy/repos',
#        'events_url': 'https://api.github.com/users/Botvy/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Botvy/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/Botvy/Botvy',
#       'description': 'Botvy - Your personal chatbot',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Botvy/Botvy',
#       'forks_url': 'https://api.github.com/repos/Botvy/Botvy/forks',
#       'keys_url': 'https://api.github.com/repos/Botvy/Botvy/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Botvy/Botvy/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Botvy/Botvy/teams',
#       'hooks_url': 'https://api.github.com/repos/Botvy/Botvy/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Botvy/Botvy/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Botvy/Botvy/events',
#       'assignees_url': 'https://api.github.com/repos/Botvy/Botvy/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Botvy/Botvy/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Botvy/Botvy/tags',
#       'blobs_url': 'https://api.github.com/repos/Botvy/Botvy/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Botvy/Botvy/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Botvy/Botvy/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Botvy/Botvy/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Botvy/Botvy/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Botvy/Botvy/languages',
#       'stargazers_url': 'https://api.github.com/repos/Botvy/Botvy/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Botvy/Botvy/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Botvy/Botvy/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Botvy/Botvy/subscription',
#       'commits_url': 'https://api.github.com/repos/Botvy/Botvy/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Botvy/Botvy/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Botvy/Botvy/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Botvy/Botvy/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Botvy/Botvy/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Botvy/Botvy/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Botvy/Botvy/merges',
#       'archive_url': 'https://api.github.com/repos/Botvy/Botvy/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Botvy/Botvy/downloads',
#       'issues_url': 'https://api.github.com/repos/Botvy/Botvy/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Botvy/Botvy/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Botvy/Botvy/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Botvy/Botvy/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Botvy/Botvy/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Botvy/Botvy/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Botvy/Botvy/deployments',
#       'created_at': '2021-02-27T22:07:40Z',
#       'updated_at': '2021-05-14T16:41:23Z',
#       'pushed_at': '2021-05-17T07:49:11Z',
#       'git_url': 'git://github.com/Botvy/Botvy.git',
#       'ssh_url': 'git@github.com:Botvy/Botvy.git',
#       'clone_url': 'https://github.com/Botvy/Botvy.git',
#       'svn_url': 'https://github.com/Botvy/Botvy',
#       'homepage': '',
#       'size': 1284,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 9,
#       'license': None,
#       'forks': 0,
#       'open_issues': 9,
#       'watchers': 1,
#       'default_branch': 'develop'}},
#     'base': {'label': 'Botvy:develop',
#      'ref': 'develop',
#      'sha': 'c995167242994bb65f31a1cd60977ee9bd718f1c',
#      'user': {'login': 'Botvy',
#       'id': 57847101,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU3ODQ3MTAx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/57847101?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Botvy',
#       'html_url': 'https://github.com/Botvy',
#       'followers_url': 'https://api.github.com/users/Botvy/followers',
#       'following_url': 'https://api.github.com/users/Botvy/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Botvy/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Botvy/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Botvy/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Botvy/orgs',
#       'repos_url': 'https://api.github.com/users/Botvy/repos',
#       'events_url': 'https://api.github.com/users/Botvy/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Botvy/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 342968461,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNDI5Njg0NjE=',
#       'name': 'Botvy',
#       'full_name': 'Botvy/Botvy',
#       'private': False,
#       'owner': {'login': 'Botvy',
#        'id': 57847101,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU3ODQ3MTAx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/57847101?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Botvy',
#        'html_url': 'https://github.com/Botvy',
#        'followers_url': 'https://api.github.com/users/Botvy/followers',
#        'following_url': 'https://api.github.com/users/Botvy/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Botvy/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Botvy/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Botvy/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Botvy/orgs',
#        'repos_url': 'https://api.github.com/users/Botvy/repos',
#        'events_url': 'https://api.github.com/users/Botvy/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Botvy/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/Botvy/Botvy',
#       'description': 'Botvy - Your personal chatbot',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Botvy/Botvy',
#       'forks_url': 'https://api.github.com/repos/Botvy/Botvy/forks',
#       'keys_url': 'https://api.github.com/repos/Botvy/Botvy/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Botvy/Botvy/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Botvy/Botvy/teams',
#       'hooks_url': 'https://api.github.com/repos/Botvy/Botvy/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Botvy/Botvy/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Botvy/Botvy/events',
#       'assignees_url': 'https://api.github.com/repos/Botvy/Botvy/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Botvy/Botvy/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Botvy/Botvy/tags',
#       'blobs_url': 'https://api.github.com/repos/Botvy/Botvy/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Botvy/Botvy/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Botvy/Botvy/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Botvy/Botvy/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Botvy/Botvy/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Botvy/Botvy/languages',
#       'stargazers_url': 'https://api.github.com/repos/Botvy/Botvy/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Botvy/Botvy/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Botvy/Botvy/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Botvy/Botvy/subscription',
#       'commits_url': 'https://api.github.com/repos/Botvy/Botvy/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Botvy/Botvy/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Botvy/Botvy/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Botvy/Botvy/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Botvy/Botvy/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Botvy/Botvy/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Botvy/Botvy/merges',
#       'archive_url': 'https://api.github.com/repos/Botvy/Botvy/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Botvy/Botvy/downloads',
#       'issues_url': 'https://api.github.com/repos/Botvy/Botvy/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Botvy/Botvy/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Botvy/Botvy/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Botvy/Botvy/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Botvy/Botvy/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Botvy/Botvy/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Botvy/Botvy/deployments',
#       'created_at': '2021-02-27T22:07:40Z',
#       'updated_at': '2021-05-14T16:41:23Z',
#       'pushed_at': '2021-05-17T07:49:11Z',
#       'git_url': 'git://github.com/Botvy/Botvy.git',
#       'ssh_url': 'git@github.com:Botvy/Botvy.git',
#       'clone_url': 'https://github.com/Botvy/Botvy.git',
#       'svn_url': 'https://github.com/Botvy/Botvy',
#       'homepage': '',
#       'size': 1284,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 9,
#       'license': None,
#       'forks': 0,
#       'open_issues': 9,
#       'watchers': 1,
#       'default_branch': 'develop'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Botvy/Botvy/pulls/103'},
#      'html': {'href': 'https://github.com/Botvy/Botvy/pull/103'},
#      'issue': {'href': 'https://api.github.com/repos/Botvy/Botvy/issues/103'},
#      'comments': {'href': 'https://api.github.com/repos/Botvy/Botvy/issues/103/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Botvy/Botvy/pulls/103/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Botvy/Botvy/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Botvy/Botvy/pulls/103/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Botvy/Botvy/statuses/935b1a63bc2cdb224ffb3dfaf20d000f6fe8e61c'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 6,
#     'deletions': 6,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2021-05-17T07:49:11Z',
#   'org': {'id': 57847101,
#    'login': 'Botvy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Botvy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57847101?'}},
#  {'id': '16383728813',
#   'type': 'PushEvent',
#   'actor': {'id': 55681227,
#    'login': 'abhishekchaturvedi10',
#    'display_login': 'abhishekchaturvedi10',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/abhishekchaturvedi10',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55681227?'},
#   'repo': {'id': 318615105,
#    'name': 'abhishekchaturvedi10/LeetCode',
#    'url': 'https://api.github.com/repos/abhishekchaturvedi10/LeetCode'},
#   'payload': {'push_id': 7129042166,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fd20ac72b264eb5cf0319bf70bb407e7311c317d',
#    'before': 'bb7cae007db861e7c01bef9ab983a4b03f33f4cd',
#    'commits': [{'sha': 'fd20ac72b264eb5cf0319bf70bb407e7311c317d',
#      'author': {'email': 'abhishek19401@iiitd.ac.in',
#       'name': 'Abhishek Chaturvedi'},
#      'message': 'Create README - LeetHub',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/abhishekchaturvedi10/LeetCode/commits/fd20ac72b264eb5cf0319bf70bb407e7311c317d'}]},
#   'public': True,
#   'created_at': '2021-05-17T07:49:11Z'},
#  {'id': '16383728795',
#   'type': 'PushEvent',
#   'actor': {'id': 54288333,
#    'login': 'otautotenant02',
#    'display_login': 'otautotenant02',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/otautotenant02',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54288333?'},
#   'repo': {'id': 203233773,
#    'name': 'otautotenant02/publishPolicyScript',
#    'url': 'https://api.github.com/repos/otautotenant02/publishPolicyScript'},
#   'payload': {'push_id': 7129042140,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '12b5510977743d996b179152dda3ffc63b8fd696',
#    'before': '55919db77844c81cc72c674057e1f2729577600f',
#    'commits': [{'sha': '12b5510977743d996b179152dda3ffc63b8fd696',
#      'author': {'email': 'otautotenant02@gmail.com',
#       'name': 'Onetrust Automation'},
#      'message': 'app-allstate-prod: Updating copied policy script run9234803',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/otautotenant02/publishPolicyScript/commits/12b5510977743d996b179152dda3ffc63b8fd696'}]},
#   'public': True,
#   'created_at': '2021-05-17T07:49:11Z'},
#  {'id': '16383728794',
#   'type': 'WatchEvent',
#   'actor': {'id': 19661184,
#    'login': 'caojianping',
#    'display_login': 'caojianping',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caojianping',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19661184?'},
#   'repo': {'id': 166680691,
#    'name': 'funtl/spring-cloud-alibaba-my-shop',
#    'url': 'https://api.github.com/repos/funtl/spring-cloud-alibaba-my-shop'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-05-17T07:49:11Z',
#   'org': {'id': 24977386,
#    'login': 'funtl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/funtl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24977386?'}},
#  {'id': '16383728785',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 52083144,
#    'login': 'architkeshri',
#    'display_login': 'architkeshri',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/architkeshri',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52083144?'},
#   'repo': {'id': 367377476,
#    'name': 'coder-oj/devjam',
#    'url': 'https://api.github.com/repos/coder-oj/devjam'},
#   'payload': {'action': 'opened',
#    'number': 12,
#    'pull_request': {'url': 'https://api.github.com/repos/coder-oj/devjam/pulls/12',
#     'id': 645621865,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjQ1NjIxODY1',
#     'html_url': 'https://github.com/coder-oj/devjam/pull/12',
#     'diff_url': 'https://github.com/coder-oj/devjam/pull/12.diff',
#     'patch_url': 'https://github.com/coder-oj/devjam/pull/12.patch',
#     'issue_url': 'https://api.github.com/repos/coder-oj/devjam/issues/12',
#     'number': 12,
#     'state': 'open',
#     'locked': False,
#     'title': 'photoshopped landing page image',
#     'user': {'login': 'architkeshri',
#      'id': 52083144,
#      'node_id': 'MDQ6VXNlcjUyMDgzMTQ0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/52083144?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/architkeshri',
#      'html_url': 'https://github.com/architkeshri',
#      'followers_url': 'https://api.github.com/users/architkeshri/followers',
#      'following_url': 'https://api.github.com/users/architkeshri/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/architkeshri/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/architkeshri/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/architkeshri/subscriptions',
#      'organizations_url': 'https://api.github.com/users/architkeshri/orgs',
#      'repos_url': 'https://api.github.com/users/architkeshri/repos',
#      'events_url': 'https://api.github.com/users/architkeshri/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/architkeshri/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2021-05-17T07:49:11Z',
#     'updated_at': '2021-05-17T07:49:11Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/coder-oj/devjam/pulls/12/commits',
#     'review_comments_url': 'https://api.github.com/repos/coder-oj/devjam/pulls/12/comments',
#     'review_comment_url': 'https://api.github.com/repos/coder-oj/devjam/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/coder-oj/devjam/issues/12/comments',
#     'statuses_url': 'https://api.github.com/repos/coder-oj/devjam/statuses/75eb3effaa0d309053db02fa7af4f2b49058b0e9',
#     'head': {'label': 'architkeshri:main',
#      'ref': 'main',
#      'sha': '75eb3effaa0d309053db02fa7af4f2b49058b0e9',
#      'user': {'login': 'architkeshri',
#       'id': 52083144,
#       'node_id': 'MDQ6VXNlcjUyMDgzMTQ0',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/52083144?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/architkeshri',
#       'html_url': 'https://github.com/architkeshri',
#       'followers_url': 'https://api.github.com/users/architkeshri/followers',
#       'following_url': 'https://api.github.com/users/architkeshri/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/architkeshri/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/architkeshri/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/architkeshri/subscriptions',
#       'organizations_url': 'https://api.github.com/users/architkeshri/orgs',
#       'repos_url': 'https://api.github.com/users/architkeshri/repos',
#       'events_url': 'https://api.github.com/users/architkeshri/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/architkeshri/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 367915529,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNjc5MTU1Mjk=',
#       'name': 'devjam',
#       'full_name': 'architkeshri/devjam',
#       'private': False,
#       'owner': {'login': 'architkeshri',
#        'id': 52083144,
#        'node_id': 'MDQ6VXNlcjUyMDgzMTQ0',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/52083144?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/architkeshri',
#        'html_url': 'https://github.com/architkeshri',
#        'followers_url': 'https://api.github.com/users/architkeshri/followers',
#        'following_url': 'https://api.github.com/users/architkeshri/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/architkeshri/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/architkeshri/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/architkeshri/subscriptions',
#        'organizations_url': 'https://api.github.com/users/architkeshri/orgs',
#        'repos_url': 'https://api.github.com/users/architkeshri/repos',
#        'events_url': 'https://api.github.com/users/architkeshri/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/architkeshri/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/architkeshri/devjam',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/architkeshri/devjam',
#       'forks_url': 'https://api.github.com/repos/architkeshri/devjam/forks',
#       'keys_url': 'https://api.github.com/repos/architkeshri/devjam/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/architkeshri/devjam/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/architkeshri/devjam/teams',
#       'hooks_url': 'https://api.github.com/repos/architkeshri/devjam/hooks',
#       'issue_events_url': 'https://api.github.com/repos/architkeshri/devjam/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/architkeshri/devjam/events',
#       'assignees_url': 'https://api.github.com/repos/architkeshri/devjam/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/architkeshri/devjam/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/architkeshri/devjam/tags',
#       'blobs_url': 'https://api.github.com/repos/architkeshri/devjam/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/architkeshri/devjam/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/architkeshri/devjam/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/architkeshri/devjam/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/architkeshri/devjam/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/architkeshri/devjam/languages',
#       'stargazers_url': 'https://api.github.com/repos/architkeshri/devjam/stargazers',
#       'contributors_url': 'https://api.github.com/repos/architkeshri/devjam/contributors',
#       'subscribers_url': 'https://api.github.com/repos/architkeshri/devjam/subscribers',
#       'subscription_url': 'https://api.github.com/repos/architkeshri/devjam/subscription',
#       'commits_url': 'https://api.github.com/repos/architkeshri/devjam/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/architkeshri/devjam/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/architkeshri/devjam/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/architkeshri/devjam/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/architkeshri/devjam/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/architkeshri/devjam/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/architkeshri/devjam/merges',
#       'archive_url': 'https://api.github.com/repos/architkeshri/devjam/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/architkeshri/devjam/downloads',
#       'issues_url': 'https://api.github.com/repos/architkeshri/devjam/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/architkeshri/devjam/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/architkeshri/devjam/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/architkeshri/devjam/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/architkeshri/devjam/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/architkeshri/devjam/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/architkeshri/devjam/deployments',
#       'created_at': '2021-05-16T15:15:29Z',
#       'updated_at': '2021-05-17T07:48:08Z',
#       'pushed_at': '2021-05-17T07:48:04Z',
#       'git_url': 'git://github.com/architkeshri/devjam.git',
#       'ssh_url': 'git@github.com:architkeshri/devjam.git',
#       'clone_url': 'https://github.com/architkeshri/devjam.git',
#       'svn_url': 'https://github.com/architkeshri/devjam',
#       'homepage': None,
#       'size': 1570,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'EJS',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'coder-oj:main',
#      'ref': 'main',
#      'sha': '4384d17694eca7f27cbe20abda86a93f65437f02',
#      'user': {'login': 'coder-oj',
#       'id': 48271607,
#       'node_id': 'MDQ6VXNlcjQ4MjcxNjA3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/48271607?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/coder-oj',
#       'html_url': 'https://github.com/coder-oj',
#       'followers_url': 'https://api.github.com/users/coder-oj/followers',
#       'following_url': 'https://api.github.com/users/coder-oj/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/coder-oj/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/coder-oj/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/coder-oj/subscriptions',
#       'organizations_url': 'https://api.github.com/users/coder-oj/orgs',
#       'repos_url': 'https://api.github.com/users/coder-oj/repos',
#       'events_url': 'https://api.github.com/users/coder-oj/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/coder-oj/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 367377476,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNjczNzc0NzY=',
#       'name': 'devjam',
#       'full_name': 'coder-oj/devjam',
#       'private': False,
#       'owner': {'login': 'coder-oj',
#        'id': 48271607,
#        'node_id': 'MDQ6VXNlcjQ4MjcxNjA3',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/48271607?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/coder-oj',
#        'html_url': 'https://github.com/coder-oj',
#        'followers_url': 'https://api.github.com/users/coder-oj/followers',
#        'following_url': 'https://api.github.com/users/coder-oj/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/coder-oj/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/coder-oj/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/coder-oj/subscriptions',
#        'organizations_url': 'https://api.github.com/users/coder-oj/orgs',
#        'repos_url': 'https://api.github.com/users/coder-oj/repos',
#        'events_url': 'https://api.github.com/users/coder-oj/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/coder-oj/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/coder-oj/devjam',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/coder-oj/devjam',
#       'forks_url': 'https://api.github.com/repos/coder-oj/devjam/forks',
#       'keys_url': 'https://api.github.com/repos/coder-oj/devjam/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/coder-oj/devjam/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/coder-oj/devjam/teams',
#       'hooks_url': 'https://api.github.com/repos/coder-oj/devjam/hooks',
#       'issue_events_url': 'https://api.github.com/repos/coder-oj/devjam/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/coder-oj/devjam/events',
#       'assignees_url': 'https://api.github.com/repos/coder-oj/devjam/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/coder-oj/devjam/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/coder-oj/devjam/tags',
#       'blobs_url': 'https://api.github.com/repos/coder-oj/devjam/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/coder-oj/devjam/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/coder-oj/devjam/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/coder-oj/devjam/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/coder-oj/devjam/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/coder-oj/devjam/languages',
#       'stargazers_url': 'https://api.github.com/repos/coder-oj/devjam/stargazers',
#       'contributors_url': 'https://api.github.com/repos/coder-oj/devjam/contributors',
#       'subscribers_url': 'https://api.github.com/repos/coder-oj/devjam/subscribers',
#       'subscription_url': 'https://api.github.com/repos/coder-oj/devjam/subscription',
#       'commits_url': 'https://api.github.com/repos/coder-oj/devjam/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/coder-oj/devjam/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/coder-oj/devjam/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/coder-oj/devjam/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/coder-oj/devjam/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/coder-oj/devjam/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/coder-oj/devjam/merges',
#       'archive_url': 'https://api.github.com/repos/coder-oj/devjam/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/coder-oj/devjam/downloads',
#       'issues_url': 'https://api.github.com/repos/coder-oj/devjam/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/coder-oj/devjam/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/coder-oj/devjam/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/coder-oj/devjam/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/coder-oj/devjam/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/coder-oj/devjam/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/coder-oj/devjam/deployments',
#       'created_at': '2021-05-14T13:51:38Z',
#       'updated_at': '2021-05-16T21:28:29Z',
#       'pushed_at': '2021-05-16T21:28:26Z',
#       'git_url': 'git://github.com/coder-oj/devjam.git',
#       'ssh_url': 'git@github.com:coder-oj/devjam.git',
#       'clone_url': 'https://github.com/coder-oj/devjam.git',
#       'svn_url': 'https://github.com/coder-oj/devjam',
#       'homepage': None,
#       'size': 2432,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'EJS',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 3,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 3,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/coder-oj/devjam/pulls/12'},
#      'html': {'href': 'https://github.com/coder-oj/devjam/pull/12'},
#      'issue': {'href': 'https://api.github.com/repos/coder-oj/devjam/issues/12'},
#      'comments': {'href': 'https://api.github.com/repos/coder-oj/devjam/issues/12/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/coder-oj/devjam/pulls/12/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/coder-oj/devjam/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/coder-oj/devjam/pulls/12/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/coder-oj/devjam/statuses/75eb3effaa0d309053db02fa7af4f2b49058b0e9'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 1,
#     'additions': 0,
#     'deletions': 0,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2021-05-17T07:49:11Z'},
#  {'id': '16383728797',
#   'type': 'PushEvent',
#   'actor': {'id': 79195483,
#    'login': 'dk8660',
#    'display_login': 'dk8660',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dk8660',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79195483?'},
#   'repo': {'id': 368092011,
#    'name': 'dk8660/dk8660.github.io',
#    'url': 'https://api.github.com/repos/dk8660/dk8660.github.io'},
#   'payload': {'push_id': 7129042153,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cd588ba105435a0fcdd7f3fe6ab57af1ef8c4689',
#    'before': 'e6b84e89a60da713989636c11bcbb9f3b3c5b341',
#    'commits': [{'sha': 'cd588ba105435a0fcdd7f3fe6ab57af1ef8c4689',
#      'author': {'email': '79195483+dk8660@users.noreply.github.com',
#       'name': 'dk8660'},
#      'message': 'Update _config.yml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dk8660/dk8660.github.io/commits/cd588ba105435a0fcdd7f3fe6ab57af1ef8c4689'}]},
#   'public': True,
#   'created_at': '2021-05-17T07:49:11Z'},
#  {'id': '16383728787',
#   'type': 'PushEvent',
#   'actor': {'id': 83683487,
#    'login': 'kiaodk104',
#    'display_login': 'kiaodk104',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kiaodk104',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83683487?'},
#   'repo': {'id': 364440357,
#    'name': 'kiaodk104/wewhje',
#    'url': 'https://api.github.com/repos/kiaodk104/wewhje'},
#   'payload': {'push_id': 7129042145,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ad1f6dd0ea4051fc10f346843f39447885b95c31',
#    'before': 'ecc0741851289d817f5866e1eced496b78e8ff48',
#    'commits': [{'sha': 'ad1f6dd0ea4051fc10f346843f39447885b95c31',
#      'author': {'email': '83683487+kiaodk104@users.noreply.github.com',
#       'name': 'kiaodk104'},
#      'message': '#add 1621237750599.update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kiaodk104/wewhje/commits/ad1f6dd0ea4051fc10f346843f39447885b95c31'}]},
#   'public': True,
#   'created_at': '2021-05-17T07:49:11Z'},
#  {'id': '16383728789',
#   'type': 'PushEvent',
#   'actor': {'id': 54351917,
#    'login': 'mytestdummy',
#    'display_login': 'mytestdummy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mytestdummy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54351917?'},
#   'repo': {'id': 348325373,
#    'name': 'mytestdummy/testaction',
#    'url': 'https://api.github.com/repos/mytestdummy/testaction'},
#   'payload': {'push_id': 7129042144,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2eeb0fc5a5d23e928fc2cb19c117d2fdd261106d',
#    'before': '540c209cb5e2c383f28b55da3216b33df4ff8bde',
#    'commits': [{'sha': '2eeb0fc5a5d23e928fc2cb19c117d2fdd261106d',
#      'author': {'email': '54351917+mytestdummy@users.noreply.github.com',
#       'name': 'mytestdummy'},
#      'message': 'Update action.yml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mytestdummy/testaction/commits/2eeb0fc5a5d23e928fc2cb19c117d2fdd261106d'}]},
#   'public': True,
#   'created_at': '2021-05-17T07:49:11Z'},
#  {'id': '16383728782',
#   'type': 'PushEvent',
#   'actor': {'id': 32487758,
#    'login': 'Chr1sDev',
#    'display_login': 'Chr1sDev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Chr1sDev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32487758?'},
#   'repo': {'id': 365146429,
#    'name': 'Chr1sDev/Current',
#    'url': 'https://api.github.com/repos/Chr1sDev/Current'},
#   'payload': {'push_id': 7129042155,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '4a2b80792a82c7f8eb52f3c64e05202a3a8cc56c',
#    'before': 'ff89cd4e177523c44ed396c9cad274a04cfc6eb1',
#    'commits': [{'sha': '4a2b80792a82c7f8eb52f3c64e05202a3a8cc56c',
#      'author': {'email': 'christopheraanderson2@gmail.com',
#       'name': 'Chr1sDev'},
#      'message': 'v1.0.4',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Chr1sDev/Current/commits/4a2b80792a82c7f8eb52f3c64e05202a3a8cc56c'}]},
#   'public': True,
#   'created_at': '2021-05-17T07:49:11Z'},
#  {'id': '16383728740',
#   'type': 'PushEvent',
#   'actor': {'id': 49942526,
#    'login': 'sverbach',
#    'display_login': 'sverbach',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sverbach',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49942526?'},
#   'repo': {'id': 297247078,
#    'name': 'sverbach/m3ts',
#    'url': 'https://api.github.com/repos/sverbach/m3ts'},
#   'payload': {'push_id': 7129042070,
#    'size': 100,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6623143c4ff1e5961a5ae057f4ce1fb3a25ff4e7',
#    'before': '5708aa6a3ed94355d7f345bac51dc0da4bf92889',
#    'commits': [{'sha': 'cb0b63993eda43f4f7dd3721852ee9ce1b80a145',
#      'author': {'email': 'chris.studer@outlook.com', 'name': 'Chris'},
#      'message': 'add tests for ready to serve detector and refactoring',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/sverbach/m3ts/commits/cb0b63993eda43f4f7dd3721852ee9ce1b80a145'},
#     {'sha': '958006e177d1a5fba64b01b77d287009d12eb2c4',
#      'author': {'email': 'chris.studer@outlook.com', 'name': 'Chris'},
#      'message': "Merge remote-tracking branch 'origin/dev' into dev\n\n# Conflicts:\n#\tapp/src/main/java/ch/m3ts/helper/OpenCVHelper.java\n#\tapp/src/main/java/ch/m3ts/tracker/visualization/live/LiveHandler.java",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/sverbach/m3ts/commits/958006e177d1a5fba64b01b77d287009d12eb2c4'},
#     {'sha': '62a40356ee261cefc47279205bcf8f152b4abd06',
#      'author': {'email': 'chris.studer@outlook.com', 'name': 'Chris'},
#      'message': 'add import',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/sverbach/m3ts/commits/62a40356ee261cefc47279205bcf8f152b4abd06'},
#     {'sha': '5c9a1e6af604d6637b96d64005a7f3d730103306',
#      'author': {'email': 'chris.studer@outlook.com', 'name': 'Chris'},
#      'message': 'add some more tests for ReadyToServeDetector',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/sverbach/m3ts/commits/5c9a1e6af604d6637b96d64005a7f3d730103306'},
#     {'sha': '7ce0c85ede6792f08295cc6b15ada24a92e8bf7e',
#      'author': {'email': 'chris.studer@outlook.com', 'name': 'Chris'},
#      'message': 'deactivate ReadyToServe gesture for replay activity #70',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/sverbach/m3ts/commits/7ce0c85ede6792f08295cc6b15ada24a92e8bf7e'},
#     {'sha': 'a1b2cabfafbe18941d1a5beb86a89526c84e410e',
#      'author': {'email': 'erbacsve@students.zhaw.ch', 'name': 'svens0hn'},
#      'message': 'add CSVBuilder as util and refactor packaging a bit',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/sverbach/m3ts/commits/a1b2cabfafbe18941d1a5beb86a89526c84e410e'},
#     {'sha': '45ce8fa5db3612bab33f8c4189e405e51b6489ef',
#      'author': {'email': 'erbacsve@students.zhaw.ch', 'name': 'svens0hn'},
#      'message': 'refactor to eventBus in EventDetector #74',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/sverbach/m3ts/commits/45ce8fa5db3612bab33f8c4189e405e51b6489ef'},
#     {'sha': 'a5ebe9819bbce52afbf3718be8b924b9e244ab0c',
#      'author': {'email': 'erbacsve@students.zhaw.ch', 'name': 'svens0hn'},
#      'message': 'fix EventDetectorTest to use EventBus',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/sverbach/m3ts/commits/a5ebe9819bbce52afbf3718be8b924b9e244ab0c'},
#     {'sha': '435b56698f241b47a18cae094cde246e7c2508d5',
#      'author': {'email': 'chris.studer@outlook.com', 'name': 'Chris'},
#      'message': 'enhance statistics logging #71',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/sverbach/m3ts/commits/435b56698f241b47a18cae094cde246e7c2508d5'},
#     {'sha': '3f6fd007109e28870d4de5ffe05658360960b6d5',
#      'author': {'email': 'chris.studer@outlook.com', 'name': 'Chris'},
#      'message': "Merge remote-tracking branch 'origin/dev' into dev",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/sverbach/m3ts/commits/3f6fd007109e28870d4de5ffe05658360960b6d5'},
#     {'sha': '46ba026d35384a2b3068de18725ec6e4c78aa389',
#      'author': {'email': 'chris.studer@outlook.com', 'name': 'Chris'},
#      'message': 'add test for track csv builder',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/sverbach/m3ts/commits/46ba026d35384a2b3068de18725ec6e4c78aa389'},
#     {'sha': '6655290c52049e8a54fcfa39491a4393af95039e',
#      'author': {'email': 'chris.studer@outlook.com', 'name': 'Chris'},
#      'message': 'add point duration to log and tests',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/sverbach/m3ts/commits/6655290c52049e8a54fcfa39491a4393af95039e'},
#     {'sha': 'f0d8f86a8494e8aefdc4927a091fe151a9c8161e',
#      'author': {'email': 'erbacsve@students.zhaw.ch', 'name': 'svens0hn'},
# ...
#       'labels_url': 'https://api.github.com/repos/wuespace/telestion-client/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/wuespace/telestion-client/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/wuespace/telestion-client/deployments',
#       'created_at': '2020-08-28T10:46:56Z',
#       'updated_at': '2021-05-16T01:26:18Z',
#       'pushed_at': '2021-05-17T07:49:11Z',
#       'git_url': 'git://github.com/wuespace/telestion-client.git',
#       'ssh_url': 'git@github.com:wuespace/telestion-client.git',
#       'clone_url': 'https://github.com/wuespace/telestion-client.git',
#       'svn_url': 'https://github.com/wuespace/telestion-client',
#       'homepage': 'https://telestion.wuespace.de',
#       'size': 36109,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 12,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 12,
#       'watchers': 2,
#       'default_branch': 'main'}},
#     'base': {'label': 'wuespace:main',
#      'ref': 'main',
#      'sha': '5ed157050bd6bc31aa508cc4a94401847f4a2cd2',
#      'user': {'login': 'wuespace',
#       'id': 80986198,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjgwOTg2MTk4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/80986198?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/wuespace',
#       'html_url': 'https://github.com/wuespace',
#       'followers_url': 'https://api.github.com/users/wuespace/followers',
#       'following_url': 'https://api.github.com/users/wuespace/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/wuespace/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/wuespace/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/wuespace/subscriptions',
#       'organizations_url': 'https://api.github.com/users/wuespace/orgs',
#       'repos_url': 'https://api.github.com/users/wuespace/repos',
#       'events_url': 'https://api.github.com/users/wuespace/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/wuespace/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 291021821,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyOTEwMjE4MjE=',
#       'name': 'telestion-client',
#       'full_name': 'wuespace/telestion-client',
#       'private': False,
#       'owner': {'login': 'wuespace',
#        'id': 80986198,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjgwOTg2MTk4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/80986198?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/wuespace',
#        'html_url': 'https://github.com/wuespace',
#        'followers_url': 'https://api.github.com/users/wuespace/followers',
#        'following_url': 'https://api.github.com/users/wuespace/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/wuespace/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/wuespace/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/wuespace/subscriptions',
#        'organizations_url': 'https://api.github.com/users/wuespace/orgs',
#        'repos_url': 'https://api.github.com/users/wuespace/repos',
#        'events_url': 'https://api.github.com/users/wuespace/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/wuespace/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/wuespace/telestion-client',
#       'description': 'Telestion Frontend Framework (Technical leads: Ludwig Richter, Jan Tischhöfer)',
#       'fork': False,
#       'url': 'https://api.github.com/repos/wuespace/telestion-client',
#       'forks_url': 'https://api.github.com/repos/wuespace/telestion-client/forks',
#       'keys_url': 'https://api.github.com/repos/wuespace/telestion-client/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/wuespace/telestion-client/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/wuespace/telestion-client/teams',
#       'hooks_url': 'https://api.github.com/repos/wuespace/telestion-client/hooks',
#       'issue_events_url': 'https://api.github.com/repos/wuespace/telestion-client/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/wuespace/telestion-client/events',
#       'assignees_url': 'https://api.github.com/repos/wuespace/telestion-client/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/wuespace/telestion-client/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/wuespace/telestion-client/tags',
#       'blobs_url': 'https://api.github.com/repos/wuespace/telestion-client/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/wuespace/telestion-client/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/wuespace/telestion-client/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/wuespace/telestion-client/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/wuespace/telestion-client/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/wuespace/telestion-client/languages',
#       'stargazers_url': 'https://api.github.com/repos/wuespace/telestion-client/stargazers',
#       'contributors_url': 'https://api.github.com/repos/wuespace/telestion-client/contributors',
#       'subscribers_url': 'https://api.github.com/repos/wuespace/telestion-client/subscribers',
#       'subscription_url': 'https://api.github.com/repos/wuespace/telestion-client/subscription',
#       'commits_url': 'https://api.github.com/repos/wuespace/telestion-client/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/wuespace/telestion-client/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/wuespace/telestion-client/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/wuespace/telestion-client/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/wuespace/telestion-client/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/wuespace/telestion-client/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/wuespace/telestion-client/merges',
#       'archive_url': 'https://api.github.com/repos/wuespace/telestion-client/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/wuespace/telestion-client/downloads',
#       'issues_url': 'https://api.github.com/repos/wuespace/telestion-client/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/wuespace/telestion-client/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/wuespace/telestion-client/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/wuespace/telestion-client/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/wuespace/telestion-client/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/wuespace/telestion-client/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/wuespace/telestion-client/deployments',
#       'created_at': '2020-08-28T10:46:56Z',
#       'updated_at': '2021-05-16T01:26:18Z',
#       'pushed_at': '2021-05-17T07:49:11Z',
#       'git_url': 'git://github.com/wuespace/telestion-client.git',
#       'ssh_url': 'git@github.com:wuespace/telestion-client.git',
#       'clone_url': 'https://github.com/wuespace/telestion-client.git',
#       'svn_url': 'https://github.com/wuespace/telestion-client',
#       'homepage': 'https://telestion.wuespace.de',
#       'size': 36109,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 12,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 12,
#       'watchers': 2,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/wuespace/telestion-client/pulls/591'},
#      'html': {'href': 'https://github.com/wuespace/telestion-client/pull/591'},
#      'issue': {'href': 'https://api.github.com/repos/wuespace/telestion-client/issues/591'},
#      'comments': {'href': 'https://api.github.com/repos/wuespace/telestion-client/issues/591/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/wuespace/telestion-client/pulls/591/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/wuespace/telestion-client/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/wuespace/telestion-client/pulls/591/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/wuespace/telestion-client/statuses/62022f576b1be2d9f0ba12ad064398c445e3ff5e'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 6,
#     'deletions': 6,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2021-05-17T07:49:11Z',
#   'org': {'id': 80986198,
#    'login': 'wuespace',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/wuespace',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80986198?'}},
#  {'id': '16383728650',
#   'type': 'PushEvent',
#   'actor': {'id': 58398485,
#    'login': 'adnane-X-tebbaa',
#    'display_login': 'adnane-X-tebbaa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/adnane-X-tebbaa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58398485?'},
#   'repo': {'id': 364868936,
#    'name': 'adnane-X-tebbaa/DownTime-Score',
#    'url': 'https://api.github.com/repos/adnane-X-tebbaa/DownTime-Score'},
#   'payload': {'push_id': 7129042084,
#    'size': 13,
#    'distinct_size': 13,
#    'ref': 'refs/heads/master',
#    'head': '76387de95448f71da40d21ba7ae76749e78221e3',
#    'before': '5cd0ef4893c601578b4716072f8b483b598dd29c',
#    'commits': [{'sha': '2707930800747ad9b1c2e4e02171599c1c34bb03',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '\U0001f7e9 DGSSI is up (200 in 1539 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adnane-X-tebbaa/DownTime-Score/commits/2707930800747ad9b1c2e4e02171599c1c34bb03'},
#     {'sha': '92183c54e742027a6de6ab68ab867d6f8200442a',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '\U0001f7e5 Covid Portal is down (0 in 0 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adnane-X-tebbaa/DownTime-Score/commits/92183c54e742027a6de6ab68ab867d6f8200442a'},
#     {'sha': '2f5c5c1583620040109ea30b867a0b814c39b638',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '\U0001f7e9 Health Portal is up (200 in 1884 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adnane-X-tebbaa/DownTime-Score/commits/2f5c5c1583620040109ea30b867a0b814c39b638'},
#     {'sha': '64418da48f23e057ddacb13116870ed74667dbc2',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '\U0001f7e9 CNSS is up (200 in 1336 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adnane-X-tebbaa/DownTime-Score/commits/64418da48f23e057ddacb13116870ed74667dbc2'},
#     {'sha': '783ed8bb707d6445a74193647d7603b02556811a',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '\U0001f7e9 Data is up (200 in 1360 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adnane-X-tebbaa/DownTime-Score/commits/783ed8bb707d6445a74193647d7603b02556811a'},
#     {'sha': '0d5a84a92ce1d3148d403bc1bada2d8e85a91ee5',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '\U0001f7e9 Douanes is up (200 in 856 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adnane-X-tebbaa/DownTime-Score/commits/0d5a84a92ce1d3148d403bc1bada2d8e85a91ee5'},
#     {'sha': '5a375296072041f9c855318e86db97aaccf5cf5a',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '\U0001f7e9 Massar Website is up (200 in 1156 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adnane-X-tebbaa/DownTime-Score/commits/5a375296072041f9c855318e86db97aaccf5cf5a'},
#     {'sha': 'cae6423f85fdd026c9765d97f6025fceaf9cf064',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '\U0001f7e9 Massar Login is up (200 in 472 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adnane-X-tebbaa/DownTime-Score/commits/cae6423f85fdd026c9765d97f6025fceaf9cf064'},
#     {'sha': 'f2b4effc21f82d0330a6038cd29f268471585418',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '\U0001f7e9 Tax Portal is up (200 in 2245 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adnane-X-tebbaa/DownTime-Score/commits/f2b4effc21f82d0330a6038cd29f268471585418'},
#     {'sha': '7df471173f9a7dd361a94a6a20d256644ded0d10',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '\U0001f7e5 ADA is down (503 in 146 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adnane-X-tebbaa/DownTime-Score/commits/7df471173f9a7dd361a94a6a20d256644ded0d10'},
#     {'sha': '7e33c5d2922b07a80e3abde6961c2ee2e9eb2891',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '\U0001f7e9 TGR Portal is up (200 in 786 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adnane-X-tebbaa/DownTime-Score/commits/7e33c5d2922b07a80e3abde6961c2ee2e9eb2891'},
#     {'sha': '6042efd3a911faa564ae7e6cd01c810d7017bbb8',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '\U0001f7e5 ANCFCC is down (0 in 0 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adnane-X-tebbaa/DownTime-Score/commits/6042efd3a911faa564ae7e6cd01c810d7017bbb8'},
#     {'sha': '76387de95448f71da40d21ba7ae76749e78221e3',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '\U0001f7e5 Auto-E Portal is down (0 in 0 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adnane-X-tebbaa/DownTime-Score/commits/76387de95448f71da40d21ba7ae76749e78221e3'}]},
#   'public': True,
#   'created_at': '2021-05-17T07:49:11Z'}]

# %%
type(r.text)
# Out:
# str

# %%
type(json.loads(r.text))
# Out:
# list

# %% [markdown]
# ### 兩者的差異：
# * 使用r.text讀出來的是純文字
# * 使用json.loads(r.text)讀出來的是列表或字典

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests

r = requests.get('https://data.epa.gov.tw/api/v1/aqx_p_13?format=json&limit=5&year_month=2021_04&api_key=9be7b239-557b-4c10-9775-78cadfc555e9') 
r.text
# Out:
# '{"include_total": true, "resource_id": "e55985ca-b7cd-40c7-86c2-10477958b798", "fields": [{"info": {"notes": "", "label": "\\u6e2c\\u7ad9\\u4ee3\\u78bc"}, "type": "text", "id": "SiteId"}, {"info": {"notes": "", "label": "\\u6e2c\\u7ad9\\u540d\\u7a31"}, "type": "text", "id": "SiteName"}, {"info": {"notes": "", "label": "\\u6e2c\\u9805\\u4ee3\\u78bc"}, "type": "text", "id": "ItemId"}, {"info": {"notes": "", "label": "\\u6e2c\\u9805\\u540d\\u7a31"}, "type": "text", "id": "ItemName"}, {"info": {"notes": "", "label": "\\u6e2c\\u9805\\u82f1\\u6587\\u540d\\u7a31"}, "type": "text", "id": "ItemEngName"}, {"info": {"notes": "", "label": "\\u6e2c\\u9805\\u55ae\\u4f4d"}, "type": "text", "id": "ItemUnit"}, {"info": {"notes": "", "label": "\\u76e3\\u6e2c\\u65e5\\u671f"}, "type": "text", "id": "MonitorDate"}, {"info": {"notes": "", "label": "0\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue00"}, {"info": {"notes": "", "label": "1\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue01"}, {"info": {"notes": "", "label": "2\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue02"}, {"info": {"notes": "", "label": "3\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue03"}, {"info": {"notes": "", "label": "4\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue04"}, {"info": {"notes": "", "label": "5\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue05"}, {"info": {"notes": "", "label": "6\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue06"}, {"info": {"notes": "", "label": "7\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue07"}, {"info": {"notes": "", "label": "8\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue08"}, {"info": {"notes": "", "label": "9\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue09"}, {"info": {"notes": "", "label": "10\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue10"}, {"info": {"notes": "", "label": "11\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue11"}, {"info": {"notes": "", "label": "12\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue12"}, {"info": {"notes": "", "label": "13\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue13"}, {"info": {"notes": "", "label": "14\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue14"}, {"info": {"notes": "", "label": "15\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue15"}, {"info": {"notes": "", "label": "16\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue16"}, {"info": {"notes": "", "label": "17\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue17"}, {"info": {"notes": "", "label": "18\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue18"}, {"info": {"notes": "", "label": "19\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue19"}, {"info": {"notes": "", "label": "20\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue20"}, {"info": {"notes": "", "label": "21\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue21"}, {"info": {"notes": "", "label": "22\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue22"}, {"info": {"notes": "", "label": "23\\u6642\\u6578\\u503c"}, "type": "text", "id": "MonitorValue23"}], "__extras": {"api_key": "9be7b239-557b-4c10-9775-78cadfc555e9"}, "records_format": "objects", "records": [{"SiteId":"6","SiteName":"板橋","ItemId":"21","ItemName":"酸雨","ItemEngName":"PH_RAIN","ItemUnit":"pH","MonitorDate":"2021-04-30","MonitorValue00":"0","MonitorValue01":"0","MonitorValue02":"0","MonitorValue03":"0","MonitorValue04":"0","MonitorValue05":"0","MonitorValue06":"0","MonitorValue07":"0","MonitorValue08":"0","MonitorValue09":"0","MonitorValue10":"0","MonitorValue11":"0","MonitorValue12":"0","MonitorValue13":"0","MonitorValue14":"0","MonitorValue15":"0","MonitorValue16":"0","MonitorValue17":"0","MonitorValue18":"0","MonitorValue19":"0","MonitorValue20":"0","MonitorValue21":"0","MonitorValue22":"0","MonitorValue23":"0"},{"SiteId":"5","SiteName":"土城","ItemId":" ...
